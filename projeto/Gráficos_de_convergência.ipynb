# %%
import pandas as pd

# %%
df1 = pd.read_csv('dados1.csv')

# %%
df1
# Out:
#     gen  nevals      Mean       Max       Min
# 0     0      20  0.736942  0.789808  0.631665
# 1     1      14  0.770158  0.785092  0.746826
# 2     2      14  0.777258  0.785092  0.765325
# 3     3      14  0.778808  0.792347  0.761697
# 4     4      14  0.782417  0.792347  0.772942
# 5     5      17  0.781538  0.792347  0.762967
# 6     6      14  0.783487  0.791440  0.764599
# 7     7      15  0.786063  0.796337  0.770947
# 8     8      13  0.786126  0.796337  0.775118
# 9     9      16  0.785900  0.795793  0.765506
# 10   10      13  0.788212  0.795974  0.772579
# 11   11       9  0.790325  0.797606  0.778564
# 12   12      19  0.791567  0.801052  0.780015
# 13   13      15  0.791794  0.803772  0.779470
# 14   14      16  0.792691  0.803772  0.776931
# 15   15      11  0.794324  0.803772  0.782009
# 16   16      13  0.792537  0.803772  0.777476
# 17   17      13  0.790497  0.803772  0.780559
# 18   18      10  0.791277  0.803772  0.777113
# ...

# %%
df2 = pd.read_csv('dados2.csv')

# %%
df2
# Out:
#     gen  nevals      Mean       Max       Min
# 0     0      20  0.545442  0.588683  0.467779
# 1     1      16  0.565361  0.585782  0.491597
# 2     2      13  0.568178  0.579011  0.551808
# 3     3      15  0.571219  0.586870  0.505985
# 4     4      15  0.576986  0.587112  0.559787
# 5     5      16  0.580583  0.592190  0.569701
# 6     6      16  0.582342  0.597993  0.561480
# 7     7       7  0.588381  0.597993  0.571636
# 8     8      16  0.584700  0.595454  0.572240
# 9     9      13  0.586023  0.596059  0.553742
# 10   10      12  0.586997  0.596059  0.574296
# 11   11      13  0.583454  0.596905  0.504292
# 12   12      11  0.587100  0.594729  0.571757
# 13   13      16  0.586948  0.595696  0.567767
# 14   14      12  0.589227  0.599202  0.576835
# 15   15      13  0.588986  0.597993  0.575626
# 16   16      15  0.590576  0.601862  0.569097
# 17   17      10  0.592728  0.601862  0.574054
# 18   18      13  0.591373  0.601862  0.581308
# ...

# %%
import matplotlib.pyplot as pyplot

# %%
def plot_generations(generation, average, minimum, maximum):
    pyplot.figure(figsize=(16, 8))
    pyplot.grid(True)
    pyplot.plot(generation, average, label="average")
    pyplot.plot(generation, minimum, label="minimum")
    pyplot.plot(generation, maximum, label="maximum")
    pyplot.xlabel("Generation")
    pyplot.ylabel("Fitness")
    pyplot.ylim(-1)
    pyplot.legend(loc="upper right")
    # pyplot.show()
    pyplot.savefig("image.png")

# %%
plot_generations(list(df1['gen']), list(df1['Mean']), list(df1['Min']), list(df1['Max']))

# %%
plot_generations(list(df2['gen']), list(df2['Mean']), list(df2['Min']), list(df2['Max']))
